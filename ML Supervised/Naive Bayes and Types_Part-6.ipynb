# %% [markdown]
# ### What is Naive Bayes?
# - Naive Bayers is a machine learning classification algorithm that predicts based on the category of a data point using probability.
# - It assumes that all the features are independent each other.
# - It performs well in real-world applicants such as sentimeny analysis, document categorisation, spam filtering.
# ### Key Features of Naive Bayes Classifiers:
# - The main idea behind the Naive Bayes Classifer is to use Bayes' Theroem to classify data based on the probabilities of different classes given the features of the data.
# - It is used mostly high-dimensional text classification.
#   1. It is a probabilistic classifier because it assumes each feature contribution to the predictions with no relation between each other.
#   2. It has very few parameters which are used to build ML models that can predict at a faster speed than other classification algorithms.

# %% [markdown]
# ### Assumption of Naive Bayes:
# - The fundamental Naive Bayes assumption is that each feature makes an:
# #### 1. Feature Independence:
# - This means when we are trying to classify something, we assume that each feature in the data does not affect any other feature.
# #### 2. Continous Features are normally distributed:
# - If a feature is continous, then it is assumed to be normally distributed within each class.
# #### 3. Discrete features have multinomial distribution:
# - If a feature is discrete, then it is assumed to be multinomial distribution within each class.
# #### 4. Features are equally important:
# - All features are assumed to contribute equally to the prediction of class label.
# #### 5. No missing values:
# - The data should not contains any missing values.

# %% [markdown]
# ### Introduction to Bayes's Theorem:
# - Bayes'Theorem provides a principled way to reverse conditional probailities.
# It is defined as -
# - Formula, p(y/X) = p(X/y).p(y) / p(X)
#   - where -
#     - p(y/X) - Posbterior probaility, probability of class y given features X.
#     - p(X/y) - Likelihood, probability of features X given class y.
#     - p(y) - Prior probability of class y.
#     - p(X) - Marginal likelihood (or) evidence.

# %% [markdown]
# ### Naive Bayes Working:
# #### 1. Terminology:
# - Consider a classification problem.Then:
#   1. y is the class label (e.g - "yes" (or) "no")
#   2. X = (x1, x2, x3, ...,xn) is the feature vector(rows).
#
# #### 2. The Naive Assumption:
# - The "naive" in Naive Bayes comes from the assumption that all features are independent given the class.That is -
#    - p(x1, x2,....,xn/y) = p(x1/y).p(x2/y)....p(xn/y)
# -Thus, Bayes'theroem becomes -
#  - p(y/x1, x2,... xn) = p(y).p(x(i)/y) / p(X)
# - Since denominator is constant for a given input, we can write:
#   - p(y/x1,x2,.....xn) ∝ p(y).p(x(i)/y)
# #### 3. Constructing the Naive Bayes Classifier:
# - We compute the posterier for each class y and choose the class with the highest probability -
#   - y^ = arg max(y) p(y).p(x(i)/y)

# %% [markdown]
# ### Types of Naivo Bayes Model:
# - There are three types of Navie Bayes Model -
#   #### 1. Gaussian Naive Bayes:
#   - It is also called as Normal distribution which plotted, it gives a bell shaped curve which is symmetric about the mean of the feature values as shown below.
#   - It continous values assoicated with each feature are assumed to be distributed according to a Gaussian Distrubution.
#   #### 2. Multinomial Naive Bayes:
#   - It is used when features are represent the frequency of terms in a document.
#   - It is commonly applied in text classification, where term frequencies are important.
#   #### 3. Bernoulli Navie Bayes:
#   - It deals with binary features, where each feature indicates wheather a word appears (or) not in a document.
#   - It is suited for scenarios where the presence (or) absence of terms is more relevant than their frequency.
#   - Both models are widely used in document classification tasks.

# %% [markdown]
# ### Types of Navie Bayes:
# #### 1. Gaussian Navie Bayes:
# - It is a type of Navie Bayes method working on continous attributes and the data features that follows Gaussian distribution throughout the dataset.
# - This "Naive" assumption simplifies calculations and makes the model fast and efficient.
# - Gaussian Navie Bayes is widely used because it performes well even with small datasets and is easy to implement and interpret.
# - Gaussian Navie Bayes assumes that the likelihhod P(x(i) / y) follows the Gaussian Distribution for each x(i) within y(k).
# - Formula will be, P(x(i) / y) = [ 1 / σ√2π ]e^-[(x-μ)²/2σ²].
# - Where,
#   - x(i) - Feature value.
#   - μ - Mean of the feature values for a given class y(k).
#   - σ - Standard deviation of the feature values for that class.
#   - π - constant
#   - e - base of the natural algorithm.

# %% [markdown]
# ### Why Gaussian Naive Bayes Works Well for Continuous Data?
# - It is a effective continous data because it assumes each feature follows a Gaussian distribution.
# - When this assumption holds true the algorithm performs well.
# - For Eg - Tasks like spam detection, medical diagnosis, predicting house prices where features such as age, income (or) height fit a normal distribution there Gaussian Navie Bayers can make accurate predictions.

# %% [markdown]
# ###  Implementation of Gaussian Naive Bayes
# #### 1.  Importing Libraries:
# - pandas - For datamanipulation.
# - load_iris - To load dataset.
# - train_test_split - To split the data into training and testing sets.
# - GaussianNB - For the Gaussian Navie Bayes classifier.
# - accuracy_score - To Evaluate the model.
# - LabelEncoder - To Encode the categorical target variable.

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #### 2. Loading the Dataset and Preparing Features and Target Variable:
# - After that we will load the Iris dataset from a CSV file names "Iris.csv" into a pandas DataFrame.
# - Then we will seperate the features(x) and the target variable (y) from the dataset.
# - Features are obtained by dropping the "Species" column.
# - Target variables is set to the "Species" column which we will be predicting.

# %%
iris = load_iris()

data = pd.DataFrame(iris.data, columns=iris.feature_names)
data['Species'] = iris.target

X = data.drop("Species", axis=1)
y = data['Species']

# %% [markdown]
# #### 3. Encoding and Splitting the Dataset:
# - Since the target variable 'Species' is categorical we will be using LabelEncoder to convert it into numerical form.
# - train_test_split() - By using this we will split the data into training and testing.
# - 70% of the data is used for training and 30% of the data is used for testing.
# - random_state - ensures reproducibility of the same data.

# %%
le = LabelEncoder()
y = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# #### 4. Creating and Training the Model
# - We will creating on Gaussian Navie Bayes Classifier(gnb).
# - Then training it on the training data using fit method.

# %%
gnb = GaussianNB()

gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# #### 5. Plotting 1D Gaussian Distributions for All Features:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

feature_names = iris.feature_names
num_features = len(feature_names)
num_classes = len(np.unique(y))

X_np = X.to_numpy() 

for feature_index in range(num_features):
    feature_name = feature_names[feature_index]
    x_vals = np.linspace(X_np[:, feature_index].min(), X_np[:, feature_index].max(), 200)

    plt.figure(figsize=(8, 4))

    for cls in range(num_classes):
        mean = gnb.theta_[cls, feature_index]
        std = np.sqrt(gnb.var_[cls, feature_index])
        y_vals = norm.pdf(x_vals, mean, std)
        plt.plot(x_vals, y_vals, label=f"Class {cls} ({iris.target_names[cls]})")

    plt.title(f"Gaussian Distribution - {feature_name}")
    plt.xlabel(feature_name)
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)

    plt.show()

# %% [markdown]
# #### 6. Making Predictions:
# - At last we will be using the trained model to make predictions on the testing data.

# %%
y_pred = gnb.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy Score: {accuracy}")
# Out:
# Accuracy Score: 0.9777777777777777
